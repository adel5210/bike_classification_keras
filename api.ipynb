# %%
pip install fastapi
# Out:
# ...
#      ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#      ---------------------------------------  81.9/84.0 kB 2.3 MB/s eta 0:00:01
#      ---------------------------------------- 84.0/84.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    ---- ----------------------------------- 41.0/394.9 kB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 153.6/394.9 kB 1.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 225.3/394.9 kB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 235.5/394.9 kB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 307.2/394.9 kB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 317.4/394.9 kB 1.1 MB/s eta 0:00:01
# ...

# %%
pip install "uvicorn[standard]"
# Out:
# ...
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------------------- 58.2/58.2 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/279.7 kB ? eta -:--:--
#    ---------- ----------------------------- 71.7/279.7 kB 4.1 MB/s eta 0:00:01
#    --------------------- ------------------ 153.6/279.7 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  276.5/279.7 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 279.7/279.7 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ----------------------------- ---------- 92.2/125.0 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 125.0/125.0 kB 2.4 MB/s eta 0:00:00
# ...
